# %% [markdown]
# <a href="https://colab.research.google.com/github/aish0606/text-detection-ctpn/blob/master/CTPN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
cd "/gdrive/My Drive"
# Out:
# /gdrive/My Drive

# %%
# !du -sh *
# Out:
# 9.8G	Codes
# 1.8M	Colab Notebooks
# 0	sroie

# %%
cd "/gdrive/My Drive/Codes"
# Out:
# [Errno 2] No such file or directory: '/gdrive/My Drive/Codes'
# /content

# %%
# !git clone "https://github.com/eragonruan/text-detection-ctpn"
# Out:
# Cloning into 'text-detection-ctpn'...
# remote: Enumerating objects: 1070, done.
# remote: Total 1070 (delta 0), reused 0 (delta 0), pack-reused 1070
# Receiving objects: 100% (1070/1070), 344.22 MiB | 15.63 MiB/s, done.
# Resolving deltas: 100% (441/441), done.

# %%
cd "/gdrive/My Drive/Codes/text-detection-ctpn"
# Out:
# /gdrive/My Drive/Codes/text-detection-ctpn

# %%
ls
# Out:
# data/  LICENSE  main/  nets/  README.md  requirements.txt  utils/

# %%
# !mkdir train_data

# %%
cd "/gdrive/My Drive/Codes/sroie/train/"
# Out:
# /gdrive/My Drive/Codes/sroie/train

# %%
cp *.txt /gdrive/My\ Drive/Codes/text-detection-ctpn/train_data/label/

# %%
cp *.jpg /gdrive/My\ Drive/Codes/text-detection-ctpn/train_data/image/

# %%
cd "/gdrive/My Drive/Codes/text-detection-ctpn"
# Out:
# /gdrive/My Drive/Codes/text-detection-ctpn

# %%
cd utils/bbox
# Out:
# /gdrive/My Drive/Codes/text-detection-ctpn/utils/bbox

# %%
# !chmod +x make.sh

# %%
! ./make.sh
# Out:
# Compiling bbox.pyx because it depends on /usr/local/lib/python3.6/dist-packages/Cython/Includes/numpy/__init__.pxd.
# [1/1] Cythonizing bbox.pyx
# /usr/local/lib/python3.6/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /gdrive/My Drive/Codes/text-detection-ctpn/utils/bbox/bbox.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# running install
# running build
# running build_ext
# building 'bbox' extension
# creating build
# creating build/temp.linux-x86_64-3.6
# x86_64-linux-gnu-gcc -pthread -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.6/dist-packages/numpy/core/include -I/usr/include/python3.6m -c bbox.c -o build/temp.linux-x86_64-3.6/bbox.o
# ...

# %%
cd "/gdrive/My Drive/Codes/text-detection-ctpn"
# Out:
# /gdrive/My Drive/Codes/text-detection-ctpn

# %%
cd "/gdrive/My Drive/Codes/text-detection-ctpn/data"
# Out:
# /gdrive/My Drive/Codes/text-detection-ctpn/data

# %%
# !wget http://download.tensorflow.org/models/vgg_16_2016_08_28.tar.gz
# Out:
# --2020-09-04 06:13:04--  http://download.tensorflow.org/models/vgg_16_2016_08_28.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 108.177.126.128, 2a00:1450:4013:c01::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|108.177.126.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 513324920 (490M) [application/x-tar]
# Saving to: ‘vgg_16_2016_08_28.tar.gz’
#
# vgg_16_2016_08_28.t 100%[===================>] 489.54M  38.6MB/s    in 13s
#
# 2020-09-04 06:13:18 (38.9 MB/s) - ‘vgg_16_2016_08_28.tar.gz’ saved [513324920/513324920]

# %%
# !tar -xvf vgg_16_2016_08_28.tar.gz
# Out:
# vgg_16.ckpt

# %%
rm vgg_16_2016_08_28.tar.gz

# %%
# !python utils/prepare/split_label.py
# Out:
#  39% 377/964 [00:40<01:07,  8.76it/s]Error processing X51006008092.jpg
#  41% 400/964 [00:43<01:01,  9.24it/s]Error processing X51006328967.jpg
#  65% 623/964 [01:19<00:34,  9.88it/s]Error processing X51006619503.jpg
#  73% 703/964 [01:29<01:36,  2.71it/s]Corrupt JPEG data: bad Huffman code
# 100% 964/964 [02:17<00:00,  7.00it/s]

# %%
# %tensorflow_version 1.4.0
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.4.0`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.

# %%
cd "/gdrive/My Drive/Codes/text-detection-ctpn"
# Out:
# /gdrive/My Drive/Codes/text-detection-ctpn

# %%
# !python ./main/train.py
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From ./main/train.py:122: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From ./main/train.py:36: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0904 10:02:27.781935 139934049064832 module_wrapper.py:139] From ./main/train.py:36: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From ./main/train.py:40: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# ...

# %%
rm -rf /gdrive/My\ Drive/Codes/text-detection-ctpn/result/output/*

# %%
cd /gdrive/My\ Drive/Codes/text-detection-ctpn
# Out:
# /gdrive/My Drive/Codes/text-detection-ctpn

# %%
# !python ./main/demo.py
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From ./main/demo.py:121: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From ./main/demo.py:60: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0920 09:41:25.445073 140191300388736 module_wrapper.py:139] From ./main/demo.py:60: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From ./main/demo.py:61: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# ...

# %%
cp X51006557193.jpg X51005724554.jpg X51005719917.jpg /gdrive/My\ Drive/Codes/text-detection-ctpn/result/input/

# %%
# !du -sh "/gdrive/My Drive/"
# Out:
# du: cannot access '/gdrive/My Drive/': No such file or directory

# %%
# !ls "/gdrive/My Drive/sroie/train" | wc -l
# Out:
# 1928

# %%
# !du -sh /gdrive/My\ Drive/Codes/text-detection-ctpn/checkpoint
# Out:
# 275M	/gdrive/My Drive/Codes/text-detection-ctpn/checkpoint

# %%
cd /gdrive/My\ Drive/Codes/text-detection-ctpn
# Out:
# /gdrive/My Drive/Codes/text-detection-ctpn

# %%
cp -r checkpoint ctpn_30000* /gdrive/My\ Drive/Codes/text-detection-ctpn/checkpoint/

# %%
# !du -sh /gdrive/My\ Drive/Codes/text-detection-ctpn/checkpoint.7z
# Out:
# 254M	/gdrive/My Drive/Codes/text-detection-ctpn/checkpoint.7z

# %%
ls /gdrive/My\ Drive/Codes/sroie/test | wc -l
# Out:
# 196

# %%
# !tar -czvf ctpn_result.tar.gz /gdrive/My\ Drive/Codes/text-detection-ctpn/result/test_output
# Out:
# tar: Removing leading `/' from member names
# /gdrive/My Drive/Codes/text-detection-ctpn/result/test_output/
# /gdrive/My Drive/Codes/text-detection-ctpn/result/test_output/X00016469672.jpg
# /gdrive/My Drive/Codes/text-detection-ctpn/result/test_output/X00016469672.txt
# /gdrive/My Drive/Codes/text-detection-ctpn/result/test_output/X51005200938.jpg
# /gdrive/My Drive/Codes/text-detection-ctpn/result/test_output/X51005200938.txt
# /gdrive/My Drive/Codes/text-detection-ctpn/result/test_output/X51005303661.jpg
# /gdrive/My Drive/Codes/text-detection-ctpn/result/test_output/X51005303661.txt
# /gdrive/My Drive/Codes/text-detection-ctpn/result/test_output/X51005361907 (1).jpg
# /gdrive/My Drive/Codes/text-detection-ctpn/result/test_output/X51005361907 (1).txt
# /gdrive/My Drive/Codes/text-detection-ctpn/result/test_output/X51005365179.jpg
# /gdrive/My Drive/Codes/text-detection-ctpn/result/test_output/X51005365179.txt
# ...

# %%
# !du -sh /gdrive/My\ Drive/Codes/text-detection-ctpn/result/test_output
# Out:
# 45M	/gdrive/My Drive/Codes/text-detection-ctpn/result/test_output

# %%
# !du -csh /gdrive/My\ Drive/Codes/text-detection-ctpn/ctpn_result.7z
# Out:
# 31M	/gdrive/My Drive/Codes/text-detection-ctpn/ctpn_result.7z
# 31M	total
